# %%
import os
import glob
import pandas as pd

# %% [markdown]
# ### READING CSV

# %%
df = pd.read_csv('data.csv',header=0, encoding='windows-1252')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ### COUNT NUMBER OF RECORDS

# %%
df.count()
# Out:
# InvoiceNo      541909
# StockCode      541909
# Description    540455
# Quantity       541909
# InvoiceDate    541909
# UnitPrice      541909
# CustomerID     406829
# Country        541909
# dtype: int64

# %% [markdown]
# ### DROPNA TO REMOVE ROW CONTAINING NULL

# %%
df.dropna()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ### DATA TYPES

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# ### HEAD

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %% [markdown]
# ### TAIL

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 541904  12/9/2011 12:50       0.85     12680.0  France
# 541905  12/9/2011 12:50       2.10     12680.0  France
# 541906  12/9/2011 12:50       4.15     12680.0  France
# 541907  12/9/2011 12:50       4.15     12680.0  France
# 541908  12/9/2011 12:50       4.95     12680.0  France

# %% [markdown]
# ### FILTERING COLUMS

# %%
df[['StockCode','Description']]
# Out:
#        StockCode                          Description
# 0         85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1          71053                  WHITE METAL LANTERN
# 2         84406B       CREAM CUPID HEARTS COAT HANGER
# 3         84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4         84029E       RED WOOLLY HOTTIE WHITE HEART.
# ...          ...                                  ...
# 541904     22613          PACK OF 20 SPACEBOY NAPKINS
# 541905     22899         CHILDREN'S APRON DOLLY GIRL
# 541906     23254        CHILDRENS CUTLERY DOLLY GIRL
# 541907     23255      CHILDRENS CUTLERY CIRCUS PARADE
# 541908     22138        BAKING SET 9 PIECE RETROSPOT
#
# [541909 rows x 2 columns]

# %% [markdown]
# ### FINDING SHAPE

# %%
df.shape
# Out:
# (541909, 8)

# %% [markdown]
# ### FILERING ROWS

# %%
df1= df[df['Country'] == 'France']
df1
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 26        536370     22728        ALARM CLOCK BAKELIKE PINK        24
# 27        536370     22727        ALARM CLOCK BAKELIKE RED         24
# 28        536370     22726       ALARM CLOCK BAKELIKE GREEN        12
# 29        536370     21724  PANDA AND BUNNIES STICKER SHEET        12
# 30        536370     21883                 STARS GIFT TAPE         24
# ...          ...       ...                              ...       ...
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID Country
# 26       12/1/2010 8:45       3.75     12583.0  France
# ...

# %% [markdown]
# ### SORTING  BY COLUMN COUNTRY

# %%
df.sort_values(by=['Country'])
# Out:
#        InvoiceNo StockCode                         Description  Quantity  \
# 344571    567085     23328  SET 6 SCHOOL MILK BOTTLES IN CRATE        12
# 270069   C560540     23240   SET OF 4 KNICK KNACK TINS DOILEY         -1
# 270070   C560540     23237      SET OF 4 KNICK KNACK TINS LEAF        -1
# 270071   C560540     23236                  DOILEY STORAGE TIN        -1
# 270072   C560540     23235            STORAGE TIN VINTAGE LEAF        -1
# ...          ...       ...                                 ...       ...
# 282768    561658    84559B            3D SHEET OF CAT STICKERS         1
# 282769    561658     84549       CROCHET WHITE RABBIT KEYRING          1
# 282770    561658     22840          ROUND CAKE TIN VINTAGE RED         1
# 282756    561658     22752        SET 7 BABUSHKA NESTING BOXES         1
# 282775    561658    47559B                 TEA TIME OVEN GLOVE         1
#
#             InvoiceDate  UnitPrice  CustomerID      Country
# ...

# %% [markdown]
# ### DROP A COLUMN

# %%
df.drop('InvoiceNo',axis=1)
# Out:
#        StockCode                          Description  Quantity  \
# 0         85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          71053                  WHITE METAL LANTERN         6
# 2         84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...                                  ...       ...
# 541904     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...

# %% [markdown]
# ### DESCRIBE BUILTIN FUNCTION

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

# %% [markdown]
# ### AGGREGRATE FUNCTIONS

# %%
df['UnitPrice'].sum()
# Out:
# 2498803.974

# %%
df['UnitPrice'].max()
# Out:
# 38970.0

# %% [markdown]
# ### GROUP BY AGGREGRATE FUNCTIONS

# %%
df.groupby('Country').sum()
# Out:
#                       Quantity    UnitPrice    CustomerID
# Country
# Australia                83653     4054.750  1.569300e+07
# Austria                   4827     1701.520  5.021102e+06
# Bahrain                    260       86.570  2.100270e+05
# Belgium                  23152     7540.130  2.571829e+07
# Brazil                     356      142.600  4.086080e+05
# Canada                    2763      910.580  2.615483e+06
# Channel Islands           9479     3738.550  1.128522e+07
# Cyprus                    6317     3920.070  7.715880e+06
# Czech Republic             592       88.150  3.834300e+05
# Denmark                   8188     1266.950  4.876734e+06
# EIRE                    142637    48447.190  1.103917e+08
# European Community         497      294.050  9.215880e+05
# Finland                  10666     3786.850  8.699324e+06
# France                  110480    43031.990  1.076489e+08
# Germany                 117448    37666.000  1.200751e+08
# ...

# %% [markdown]
# ### COPY DATAFRAME

# %%
dataframe = df.copy()
dataframe
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %% [markdown]
# ### TRANSPOSE DATAFRAME

# %%
Transpose = dataframe.T
Transpose
# Out:
#                                          0                    1       \
# InvoiceNo                                536365               536365
# StockCode                                85123A                71053
# Description  WHITE HANGING HEART T-LIGHT HOLDER  WHITE METAL LANTERN
# Quantity                                      6                    6
# InvoiceDate                      12/1/2010 8:26       12/1/2010 8:26
# UnitPrice                                  2.55                 3.39
# CustomerID                              17850.0              17850.0
# Country                          United Kingdom       United Kingdom
#
#                                      2       \
# InvoiceNo                            536365
# StockCode                            84406B
# Description  CREAM CUPID HEARTS COAT HANGER
# Quantity                                  8
# InvoiceDate                  12/1/2010 8:26
# UnitPrice                              2.75
# ...

# %% [markdown]
# ### READING HTML

# %%
df = pd.read_html('http://www.forex.com.pk/')
df
# Out:
# [                                                   0  \
#  0  <!-- google_ad_client = "pub-7950283822312113"...
#  1  <!-- google_ad_client = "pub-7950283822312113"...
#  2  Home  Open Market Rates  Inter Bank Rates  Int...
#  3  Home - Open Market Rates -Inter Bank Rates - F...
#  4  Copyright © 2006-2011 Forex.com.pk All Rights ...
#  5                                                NaN
#
#                                                     1  \
#  0  <!-- google_ad_client = "pub-7950283822312113"...
#  1  <!-- google_ad_client = "pub-7950283822312113"...
#  2  Home  Open Market Rates  Inter Bank Rates  Int...
#  3  Home - Open Market Rates -Inter Bank Rates - F...
#  4  Copyright © 2006-2011 Forex.com.pk All Rights ...
#  5                                                NaN
#
#                                                     2
#  0  <!-- google_ad_client = "pub-7950283822312113"...
#  1  <!-- google_ad_client = "pub-7950283822312113"...
# ...

# %%
df[11]
# Out:
#                                                     0  \
# 0   FOREX RATES \tPakistan Open Market Forex Rates...
# 1                                            Currency
# 2                                   Australian Dollar
# 3                                     Canadian Dollar
# 4                                          China Yuan
# 5                                                Euro
# 6                                        Japanese Yen
# 7                                         Saudi Riyal
# 8                                        U.A.E Dirham
# 9                                   UK Pound Sterling
# 10                                          US Dollar
#
#                                                     1  \
# 0   FOREX RATES \tPakistan Open Market Forex Rates...
# 1                                              Buying
# 2                                              145.58
# 3                                              160.89
# ...

# %% [markdown]
# ### READ MULTIPLE CSV

# %%
os.chdir("/home/abdulbaqui/Github/Libraries/data/")
file_extension ='.csv'
all_file_name = [i for i in glob.glob(f"*{file_extension}")]
all_file_name
# Out:
# ['hw_200.csv', 'freshman_kgs.csv', 'addresses.csv', 'cities.csv', 'hooke.csv', 'airtravel.csv', 'grades.csv', 'example.csv', 'freshman_lbs.csv', 'hurricanes.csv', 'crash_catalonia.csv', 'faithful.csv', 'ford_escort.csv', 'biostats.csv', 'homes.csv']

# %%
df = pd.concat([pd.read_csv(file,delimiter=',') for file in all_file_name])
df
# Out:
#     Index   Height(Inches)"   "Weight(Pounds)"  Sex   "Weight (Sep)"  \
# 0     1.0             65.78             112.99  NaN              NaN
# 1     2.0             71.52             136.49  NaN              NaN
# 2     3.0             69.40             153.03  NaN              NaN
# 3     4.0             68.22             142.34  NaN              NaN
# 4     5.0             67.79             144.30  NaN              NaN
# ..    ...               ...                ...  ...              ...
# 45    NaN               NaN                NaN  NaN              NaN
# 46    NaN               NaN                NaN  NaN              NaN
# 47    NaN               NaN                NaN  NaN              NaN
# 48    NaN               NaN                NaN  NaN              NaN
# 49    NaN               NaN                NaN  NaN              NaN
#
#      "Weight (Apr)"   "BMI (Sep)"   "BMI (Apr)" John  Doe  ...  "Height (in)"  \
# ...
